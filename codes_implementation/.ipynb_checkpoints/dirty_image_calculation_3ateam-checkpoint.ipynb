# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from astropy.time import Time

from image_code import image_calculation_functions as ic




# %load_ext autoreload
# %autoreload 2

# %%
theta_p = 181
phi_p = 361
phi = np.linspace(-180,180,phi_p)*np.pi/180
theta = np.linspace(0,90,int(theta_p/2)+1)*np.pi/180
P,T = np.meshgrid(phi,theta)

# %%
beam_squarel,ethetal, ephil=read_feko('dipole_0p1-1MHz_regolith-0',31,theta_p,phi_p)
beam_squarel90,ethetal90,ephil90=read_feko('dipole_0p1-1MHz_regolith-90',31,theta_p,phi_p)

beam_squareh,ethetah, ephih = read_feko('dipole_0p4-40MHz_regolith',10,theta_p,phi_p)
beam_squareh90,ethetah90,ephih90 = read_feko('dipole_0p4-40MHz_regolith-90',10,theta_p,phi_p)

# %%
factor =500


#P,T = np.meshgrid(phi,theta)
l_grid = np.linspace(-1,1,int(factor))
m_grid = l_grid
L,M = np.meshgrid(l_grid,m_grid)
q = L**2+M**2
el = np.sqrt(1 - q)
el[q>=1] = 0

p = -np.arctan2(M,L)#-np.arctan2(M,L)#
t = np.pi/2 - np.arcsin(el)#-np.arcsin(L,(np.sin(p)))+np.pi/2
# Out:
# <ipython-input-2-2ba9f413492e>:13: RuntimeWarning: invalid value encountered in sqrt
#   el = np.sqrt(1 - q)

# %%
sample = 1

if sample==0:
    wav = 500 #in m; f = 0.6 MHz
    index = 17
    beam_square,etheta, ephi = beam_squarel,ethetal, ephil
    beam_square90,etheta90,ephi90 = beam_squarel90,ethetal90,ephil90
    
elif sample==1:
    wav = 150 # in m; f = 2MHz
    index = 3
    beam_square,etheta, ephi = beam_squareh,ethetah, ephih
    beam_square90,etheta90,ephi90=beam_squareh90,ethetah90,ephih90
   
    
elif sample==2:
    
    wav = 30 # in m; f = 10MHz
    index = 4
    beam_square,etheta, ephi = beam_squareh,ethetah, ephih
    beam_square90,etheta90,ephi90=beam_squareh90,ethetah90,ephih90
    

f = 300/wav
####Normalizing by 2 MHz
etheta = np.roll(etheta,180,axis=2)/np.max(ethetah[3,:,:])
etheta90 = np.roll(etheta90,180,axis=2)/np.max(ethetah90[3,:,:])
ephi = np.roll(ephi,180,axis=2)/np.max(ephih[3,:,:])
ephi90 = np.roll(ephi90,180,axis=2)/np.max(ephih90[3,:,:])

# %%
beam_etheta = beam_interpolate(etheta[index],theta,phi,t,p)
beam_etheta90 = beam_interpolate(etheta90[index],theta,phi,t,p)

beam_ephi = beam_interpolate(ephi[index],theta,phi,t,p)
beam_ephi90 = beam_interpolate(ephi90[index],theta,phi,t,p)

# %%
far_array=np.load('farside_array_nooffset.npy')

# %%
off = np.linspace(-12,12,24)*u.hour
cyg_a_altaz = np.zeros((len(off),2))
cyg_A = processed_source()



for i in range(len(off)):
    cyg_A.init_skycoord('19 59 28.35645829 +40 44 02.0966496', Time.now()+off[i])
    cyg_a_altaz[i] = cyg_A.obj_a_altaz
    
s_index = np.where(cyg_a_altaz == np.max(cyg_a_altaz[:,0]))[0]
time = Time.now()+off[11]

# %%
t2 = Time(time, scale='utc',location=('180d', '0d'))
lst = t2.sidereal_time('apparent').value
print(t2,lst)
# Out:
# 2021-10-14 04:44:39.584358 18.274610066162467

# %%
cyg_A.init_skycoord('19 59 28.35645829 +40 44 02.0966496', time)

cas_A = processed_source()
cas_A.init_skycoord('23 23 24.000 +58 48 54.00',time)

tau_A = processed_source()
tau_A.init_skycoord('05 34 31.94 +22 00 52.2 ',time)

sgr_A = processed_source()
sgr_A.init_skycoord('17 45 40.03599 -29 00 28.1699',time)

# %%
cyg_A.init_skymap(theta_p,phi_p,13500)
tau_A.init_skymap(theta_p,phi_p,10000)
tau_A.plot_skymap()
cas_A.init_skymap(theta_p,phi_p,28000)
sgr_A.init_skymap(theta_p,phi_p,10000)

# %%
cyg_A.tp_to_lm(theta,phi,l_grid,m_grid,t,p)
cas_A.tp_to_lm(theta,phi,l_grid,m_grid,t,p)
sgr_A.tp_to_lm(theta,phi,l_grid,m_grid,t,p)
tau_A.tp_to_lm(theta,phi,l_grid,m_grid,t,p)
# Out:
# [47]
# here
# [83]
# here
# [29]
# here
# [155]

# %%
cyg_A.calculate_ha_dec(lst)
cas_A.calculate_ha_dec(lst)
sgr_A.calculate_ha_dec(lst)

# %%
np.where(sgr_A.sky_map!=0)
# Out:
# (array([275]), array([132]))

# %%
sgr_A.sky_map[275,132] = 0
sgr_A.sky_map[250,250] = 10000

# %%
cyg_A.calculate_delphi(50,wav,L,M)
cas_A.calculate_delphi(50,wav,L,M)
sgr_A.calculate_delphi(50,wav,L,M)

# %%
J = np.array([[beam_etheta,beam_ephi] ,[beam_etheta90,beam_ephi90]])

# %%
cyg_A.make_sky_coherence()
cas_A.make_sky_coherence()
sgr_A.make_sky_coherence()

cyg_A.make_offset_jacob(J)
cas_A.make_offset_jacob(J)
sgr_A.make_offset_jacob(J)

# %%
cyg_A.make_pseudo_vis(J)
sgr_A.make_pseudo_vis(J)
cas_A.make_pseudo_vis(J)

# %%
fig,ax = plt.subplots(1,1, subplot_kw=dict(polar=True),figsize=(4,4))
p1 =ax.pcolormesh(p,t,np.abs(cyg_A.sky_map),cmap='Spectral_r',norm=LogNorm())    #,vmin=0, vmax = 0.0005)  
plt.colorbar(p1, ax=ax,label='Jy')

# %%
cyg_A.invert_offset_jacob()
cyg_A.offset_ft()

cas_A.invert_offset_jacob()
cas_A.offset_ft()

sgr_A.invert_offset_jacob()
sgr_A.offset_ft()

# %%
cyg_A.uvcal(wav,far_array)
cyg_A.make_dirty_image(off_c=0)

cas_A.uvcal(wav,far_array)
cas_A.make_dirty_image(off_c=0)


sgr_A.uvcal(wav,far_array)
sgr_A.make_dirty_image(off_c=0)

# %%
corrected_cyg=offset_correction(cyg_A.J_in,cyg_A.image_off)
corrected_cas=offset_correction(cas_A.J_in,cas_A.image_off)
corrected_sgr=offset_correction(sgr_A.J_in,sgr_A.image_off)

# %%
final = np.zeros((4, np.shape(cas_A.beam_ft)[2],np.shape(cas_A.beam_ft)[3]),dtype = np.complex128)
final_off = np.zeros((4, np.shape(cas_A.beam_ft)[2],np.shape(cas_A.beam_ft)[3]),dtype = np.complex128)
final_offc = np.zeros((4,np.shape(cas_A.beam_ft)[2],np.shape(cas_A.beam_ft)[3]),dtype = np.complex128)

fig,ax = plt.subplots(4,3, subplot_kw=dict(polar=True),figsize=(12,16))
text = ['XX','XY','YX','YY']
c =0
for i in range(2):
    for j in range(2):
           
      
        final[c] = sgr_A.image[i,j] #+ sgr_A.image[i] + cas_A.image[i] +
        final_off[c] =  sgr_A.image_off[i,j] #+ sgr_A.image_off[i] + cas_A.image_off[i] +
        final_offc[c] = corrected_sgr[i,j]#image_f[i,j]
        c = c+1
for i in  range(4):
    fig.suptitle('Dipole beam on regolith @ '+ str(f)+'MHz',fontsize=18,y=0.95)  
    
    p1 =ax[int(i%4),0].pcolormesh(p,t,np.real(final[i]),cmap='Spectral_r')#,norm=LogNorm())    #,vmin=0, vmax = 0.0005)  
    plt.colorbar(p1, ax=ax[int(i%4),0])
    ax[int(i%4),0].set_title(text[i], pad=25, fontsize = 18)
    ax[int(i%4),0].set_rlabel_position(50)
    plt.ylabel('theta(deg)')
    plt.xlabel('phi(deg)')
    ax[0,0].text(1.75,2.5,'No Offset', fontsize=18)
    
    p1 =ax[int(i%4),1].pcolormesh(p,t,np.real( final_off[i]),cmap='Spectral_r')    #,vmin=0, vmax = 0.0005)  
    plt.colorbar(p1, ax=ax[int(i%4),1])
    ax[int(i%4),1].set_rlabel_position(50)
    plt.ylabel('theta(deg)')
    plt.xlabel('phi(deg)')
    ax[0,1].text(1.75,2.5,'No offset - 50m offset', fontsize=18)
    
    p1 =ax[int(i%4),2].pcolormesh(p,t,np.real( final_offc[i]),cmap='Spectral_r')    #,vmin=0, vmax = 0.0005)  
    plt.colorbar(p1, ax=ax[int(i%4),2])
    ax[int(i%4),2].set_rlabel_position(50)
    plt.ylabel('theta(deg)')
    plt.xlabel('phi(deg)')
    ax[0,2].text(1.75,2.5,r'No offset - Corrected ', fontsize=18)

# %%
sky_pol = beamtopol(final)
sky_pol_off = beamtopol(final_off)
sky_pol_offc = beamtopol(final_offc)

# %%
text = ['I', 'Q', 'U', 'V']
fig2,ax2 = plt.subplots(4,3, subplot_kw=dict(polar=True),figsize=(12,16))

fig2.suptitle('Dipole beam on regolith @ '+ str(f)+'MHz',fontsize=18,y=0.95)

for i in range(4):
    p2 = ax2[int(i%4),0].pcolormesh(p,t,np.real(sky_pol[i]),cmap='coolwarm')#,norm=LogNorm())#,vmin=0, vmax = 0.0005)  
    plt.colorbar(p2, ax=ax2[int(i%4),0],label='Jy')
    #hb.Label.String = 'Jy'
    plt.ylabel('theta(deg)')
    plt.xlabel('phi(deg)')
    ax2[int(i%4),0].set_title(text[i], pad=25, fontsize = 18)
    ax2[0,0].text(1.75,2.5,'No offset', fontsize=18)
    ax2[int(i%4),0].set_rlabel_position(50)


###########################################################################################

    p2 = ax2[int(i%4),1].pcolormesh(p,t,np.real( sky_pol_off[i]),cmap='coolwarm')#,vmin=0, vmax = 0.0005)  
    plt.colorbar(p2, ax=ax2[int(i%4),1])
    plt.ylabel('theta(deg)')
    plt.xlabel('phi(deg)')
    ax2[0,1].text(1.75,2.5,'With 50m offset', fontsize=18)
    ax2[int(i%4),1].set_rlabel_position(50)

#########################################################################################
    if i==3:
        vmin=-1.1
        vmax=0.01
        p2 = ax2[int(i%4),2].pcolormesh(p,t,np.real( sky_pol_offc[i]),cmap='coolwarm',vmin=vmin, vmax = vmax)  
    else:
        p2 = ax2[int(i%4),2].pcolormesh(p,t,np.real( sky_pol_offc[i]),cmap='coolwarm')#,vmin=vmin, vmax = vmax)
    plt.colorbar(p2, ax=ax2[int(i%4),2])
    plt.ylabel('theta(deg)')
    plt.xlabel('phi(deg)')
    ax2[0,2].text(1.75,2.5,r'Corrected', fontsize=18)
    ax2[int(i%4),2].set_rlabel_position(50)

# %%
x = np.where(cyg_A.sky_map==np.max(cyg_A.sky_map))
x1 = np.where(cas_A.sky_map==np.max(cas_A.sky_map))
x2 = np.where(sgr_A.sky_map==np.max(sgr_A.sky_map))


print(cas_A.alt,cas_A.az,cyg_A.alt,cyg_A.az,sgr_A.alt,sgr_A.az)
#print(cyg_A.obj_a.ra.deg,cyg_A.obj_a.dec.deg)


print(lmtotp(L[x[0],x[1]],M[x[0],x[1]])[0]*180/np.pi, lmtotp(L[x[0],x[1]],M[x[0],x[1]])[1]*180/np.pi)
print(lmtotp(L[x1[0],x1[1]],M[x1[0],x1[1]])[0]*180/np.pi, lmtotp(L[x1[0],x1[1]],M[x1[0],x1[1]])[1]*180/np.pi)
print(lmtotp(L[x2[0],x2[1]],M[x2[0],x2[1]])[0]*180/np.pi, lmtotp(L[x2[0],x2[1]],M[x2[0],x2[1]])[1]*180/np.pi)


#print(lmtotp(L[]))
